# %%
import pandas as pd
import numpy as np
from random import random

# %%
df = pd.read_csv("electronics_sales.csv", parse_dates=["date"])

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 60 entries, 0 to 59
# Data columns (total 10 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   order_id    60 non-null     int64
#  1   date        60 non-null     datetime64[ns]
#  2   customer    60 non-null     object
#  3   region      60 non-null     object
#  4   product     60 non-null     object
#  5   units       60 non-null     int64
#  6   unit_price  60 non-null     float64
#  7   returned    60 non-null     bool
#  8   notes       50 non-null     object
#  9   revenue     60 non-null     float64
# dtypes: bool(1), datetime64[ns](1), float64(2), int64(2), object(4)
# memory usage: 4.4+ KB

# %% [markdown]
# pandas stores each column as a NumPy array internally, so dtype matters for performance.

# %%
print(df.describe()  )     # numeric columns summary
df.describe(include='all')  # includes categorical columns
# Out:
#           order_id                 date      units    unit_price  \
# count    60.000000                   60  60.000000     60.000000
# mean   2030.500000  2025-01-30 12:00:00   4.850000  24610.381500
# min    2001.000000  2025-01-01 00:00:00   1.000000   1248.020000
# 25%    2015.750000  2025-01-15 18:00:00   2.000000  12071.017500
# 50%    2030.500000  2025-01-30 12:00:00   5.000000  27570.460000
# 75%    2045.250000  2025-02-14 06:00:00   7.000000  35151.340000
# max    2060.000000  2025-03-01 00:00:00   9.000000  46899.770000
# std      17.464249                  NaN   2.729779  14234.553392
#
#              revenue
# count      60.000000
# mean   118680.795667
# min      1248.020000
# 25%     44169.992500
# 50%     89284.000000
# 75%    171809.347500
# max    416789.910000
# std    100570.565700
#            order_id                 date customer region product      units  \
# count     60.000000                   60       60     60      60  60.000000
# unique          NaN                  NaN       28      4       6        NaN
# top             NaN                  NaN      Ira  South  Laptop        NaN
# freq            NaN                  NaN        4     22      15        NaN
# mean    2030.500000  2025-01-30 12:00:00      NaN    NaN     NaN   4.850000
# min     2001.000000  2025-01-01 00:00:00      NaN    NaN     NaN   1.000000
# 25%     2015.750000  2025-01-15 18:00:00      NaN    NaN     NaN   2.000000
# 50%     2030.500000  2025-01-30 12:00:00      NaN    NaN     NaN   5.000000
# 75%     2045.250000  2025-02-14 06:00:00      NaN    NaN     NaN   7.000000
# max     2060.000000  2025-03-01 00:00:00      NaN    NaN     NaN   9.000000
# std       17.464249                  NaN      NaN    NaN     NaN   2.729779
#
#           unit_price returned   notes        revenue
# count      60.000000       60      50      60.000000
# unique           NaN        2       4            NaN
# top              NaN    False  Urgent            NaN
# freq             NaN       56      15            NaN
# mean    24610.381500      NaN     NaN  118680.795667
# min      1248.020000      NaN     NaN    1248.020000
# 25%     12071.017500      NaN     NaN   44169.992500
# 50%     27570.460000      NaN     NaN   89284.000000
# 75%     35151.340000      NaN     NaN  171809.347500
# max     46899.770000      NaN     NaN  416789.910000
# std     14234.553392      NaN     NaN  100570.565700

# %%
df.loc[:5]
# Out:
#    order_id       date customer region     product  units  unit_price  \
# 0      2001 2025-01-01     Diya   East  Headphones      5    38319.36
# 1      2002 2025-01-02  Reyansh   East  Smartphone      7    12644.24
# 2      2003 2025-01-03      Sai  North  Headphones      7    36682.60
# 3      2004 2025-01-04     Sara  North  Smartphone      4    19021.37
# 4      2005 2025-01-05    Aditi   East      Laptop      7    31982.99
# 5      2006 2025-01-06    Anika  South  Smartwatch      3    32042.96
#
#    returned          notes    revenue
# 0     False            NaN  191596.80
# 1     False  Promo Applied   88509.68
# 2     False           Gift  256778.20
# 3     False  Promo Applied   76085.48
# 4     False         Urgent  223880.93
# 5      True         Urgent   96128.88

# %% [markdown]
# ##### Columns

# %%
df["customer"].head()       # returns a Series
df[["customer","region"]].head()  # returns a DataFrame
# Columns are internally Series objects, can be manipulated like Series.
# Out:
#   customer region
# 0     Diya   East
# 1  Reyansh   East
# 2      Sai  North
# 3     Sara  North
# 4    Aditi   East

# %% [markdown]
# ##### Rows

# %%
# By position: .iloc
df.iloc[0:3]
# Out:
#    order_id       date customer region     product  units  unit_price  \
# 0      2001 2025-01-01     Diya   East  Headphones      5    38319.36
# 1      2002 2025-01-02  Reyansh   East  Smartphone      7    12644.24
# 2      2003 2025-01-03      Sai  North  Headphones      7    36682.60
#
#    returned          notes    revenue
# 0     False            NaN  191596.80
# 1     False  Promo Applied   88509.68
# 2     False           Gift  256778.20

# %%
# By label/index: .loc

df.loc[1:3]
df.loc[0]
# Out:
# order_id                     2001
# date          2025-01-01 00:00:00
# customer                     Diya
# region                       East
# product                Headphones
# units                           5
# unit_price               38319.36
# returned                    False
# notes                         NaN
# revenue                  191596.8
# Name: 0, dtype: object

# %% [markdown]
# ##### Cells

# %%
print(df.at[0, "customer"])     # faster for scalar
print(df.iat[0, 2])     # by position
print(df.loc[0, "revenue"])     # label-based
df.head()
# Out:
# Diya
# Diya
# 191596.8
#    order_id       date customer region     product  units  unit_price  \
# 0      2001 2025-01-01     Diya   East  Headphones      5    38319.36
# 1      2002 2025-01-02  Reyansh   East  Smartphone      7    12644.24
# 2      2003 2025-01-03      Sai  North  Headphones      7    36682.60
# 3      2004 2025-01-04     Sara  North  Smartphone      4    19021.37
# 4      2005 2025-01-05    Aditi   East      Laptop      7    31982.99
#
#    returned          notes    revenue
# 0     False            NaN  191596.80
# 1     False  Promo Applied   88509.68
# 2     False           Gift  256778.20
# 3     False  Promo Applied   76085.48
# 4     False         Urgent  223880.93

# %% [markdown]
# Adding / Modifying / Deleting Columns

# %%
# Adding a column
df['Profit'] = df['revenue'] * 0.15
df.head(2)
# Out:
#    order_id       date customer region     product  units  unit_price  \
# 0      2001 2025-01-01     Diya   East  Headphones      5    38319.36
# 1      2002 2025-01-02  Reyansh   East  Smartphone      7    12644.24
#
#    returned          notes    revenue     Profit
# 0     False            NaN  191596.80  28739.520
# 1     False  Promo Applied   88509.68  13276.452

# %%
# Modifying a column
df["units"] = df["units"] + 1
df.rename(columns={'Profit': 'profit'}, inplace=True)
df.head()
# Out:
#    order_id       date customer region     product  units  unit_price  \
# 0      2001 2025-01-01     Diya   East  Headphones      6    38319.36
# 1      2002 2025-01-02  Reyansh   East  Smartphone      8    12644.24
# 2      2003 2025-01-03      Sai  North  Headphones      8    36682.60
# 3      2004 2025-01-04     Sara  North  Smartphone      5    19021.37
# 4      2005 2025-01-05    Aditi   East      Laptop      8    31982.99
#
#    returned          notes    revenue      profit
# 0     False            NaN  191596.80  28739.5200
# 1     False  Promo Applied   88509.68  13276.4520
# 2     False           Gift  256778.20  38516.7300
# 3     False  Promo Applied   76085.48  11412.8220
# 4     False         Urgent  223880.93  33582.1395

# %%
# Deleting a column
# del df["notes"]
df.drop("returned", axis=1, inplace=False)
# df.head()
# Out:
#    order_id       date customer region     product  units  unit_price  \
# 0      2001 2025-01-01     Diya   East  Headphones      5    38319.36
# 1      2002 2025-01-02  Reyansh   East  Smartphone      7    12644.24
# 2      2003 2025-01-03      Sai  North  Headphones      7    36682.60
# 3      2004 2025-01-04     Sara  North  Smartphone      4    19021.37
# 4      2005 2025-01-05    Aditi   East      Laptop      7    31982.99
#
#    returned          notes    revenue      Profit
# 0     False            NaN  191596.80  28739.5200
# 1     False  Promo Applied   88509.68  13276.4520
# 2     False           Gift  256778.20  38516.7300
# 3     False  Promo Applied   76085.48  11412.8220
# 4     False         Urgent  223880.93  33582.1395

# %% [markdown]
# ##### Filtering / Boolean Indexing

# %%
df[df['units'] > 8]

df[(df["region"]=="North") & (df["units"]>=6)]
df.query('region=="South" and revenue>200000')

# query() is cleaner for complex conditions
# Internal working: creates a boolean mask and applies vectorized filtering
# Out:
#     order_id       date customer region     product  units  unit_price  \
# 13      2014 2025-01-14    Aditi  South      Laptop      9    34200.65
# 26      2027 2025-01-27   Ishaan  South  Smartphone      5    43989.63
# 29      2030 2025-01-30     Pari  South      Laptop      8    41043.89
# 41      2042 2025-02-11   Raghav  South      Tablet      5    44467.23
# 57      2058 2025-02-27   Yuvraj  South  Smartwatch      7    35896.78
#
#     returned          notes    revenue      Profit
# 13     False  Promo Applied  307805.85  46170.8775
# 26     False  Promo Applied  219948.15  32992.2225
# 29     False     Bulk Order  328351.12  49252.6680
# 41     False     Bulk Order  222336.15  33350.4225
# 57     False           Gift  251277.46  37691.6190

# %% [markdown]
# ##### Sorting

# %%
df.sort_values(['region','revenue'], ascending=[True, False]).head()
# Out:
#     order_id       date customer region     product  units  unit_price  \
# 25      2026 2025-01-26   Ishita   East  Smartphone      9    46309.99
# 4       2005 2025-01-05    Aditi   East      Laptop      7    31982.99
# 0       2001 2025-01-01     Diya   East  Headphones      5    38319.36
# 20      2021 2025-01-21  Krishna   East      Tablet      9    19950.03
# 1       2002 2025-01-02  Reyansh   East  Smartphone      7    12644.24
#
#     returned          notes    revenue      Profit
# 25     False     Bulk Order  416789.91  62518.4865
# 4      False         Urgent  223880.93  33582.1395
# 0      False            NaN  191596.80  28739.5200
# 20      True  Promo Applied  179550.27  26932.5405
# 1      False  Promo Applied   88509.68  13276.4520

# %% [markdown]
# ##### Handling Missing Data

# %%
df.isna().sum()
# Out:
# order_id       0
# date           0
# customer       0
# region         0
# product        0
# units          0
# unit_price     0
# returned       0
# notes         10
# revenue        0
# Profit         0
# dtype: int64

# %%
df['notes'].fillna('None').head(10)
# Out:
# 0             None
# 1    Promo Applied
# 2             Gift
# 3    Promo Applied
# 4           Urgent
# 5           Urgent
# 6             Gift
# 7             None
# 8           Urgent
# 9       Bulk Order
# Name: notes, dtype: object

# %%
df.iloc()

# %%
dafr = pd.DataFrame(
    {
        "a": [1,2,3,4, None],
        "b": [1,2,None, 3,4],
        "c": [None, 1,2,3,4]
    }
)

print((dafr + dafr == 2 * dafr).all().all()) 
print((dafr + dafr).equals(dafr * 2))
# Out:
# False
# True

# %% [markdown]
# #### Pandas – Function Application

# %% [markdown]
# ##### Table-wise Function Application with pipe()
#
# **pipe()** allows you to **chain multiple operations** in a clean and functional style, applying them to the whole DataFrame.

# %%
def add_profit(df):
    df['profit'] = df['revenue'] * 0.1  # vectoriztion
    return df

def add_discount(df, threshold=20000):
    df['discount'] = df['revenue'].apply(lambda x: x * 0.05 if x > threshold else 0)
    return df


result = (df
          .pipe(add_profit)
          .pipe(add_discount, threshold=25000)
          .pipe(lambda d: d.sort_values("customer", ascending=True))
         )

# pipe() passes the whole DataFrame to each function.
# You can chain multiple transformations without nested parentheses.
# Improves readability in complex data processing pipelines.

result.head(10)
# Out:
#     order_id       date customer region     product  units  unit_price  \
# 31      2032 2025-02-01    Aarav   West  Smartphone      8    26952.88
# 4       2005 2025-01-05    Aditi   East      Laptop      7    31982.99
# 12      2013 2025-01-13    Aditi  North      Laptop      7    29953.75
# 13      2014 2025-01-14    Aditi  South      Laptop      9    34200.65
# 58      2059 2025-02-28   Aditya   West  Headphones      4    12625.21
# 19      2020 2025-01-20   Aditya   West      Laptop      4    34855.95
# 59      2060 2025-03-01   Ananya  North  Smartwatch      7    16944.59
# 5       2006 2025-01-06    Anika  South  Smartwatch      3    32042.96
# 17      2018 2025-01-18    Anika   West      Tablet     10    32613.47
# 38      2039 2025-02-08     Anvi  South      Tablet      2    18111.27
#
#     returned          notes    revenue     profit    discount
# 31     False  Promo Applied  215623.04  21562.304  10781.1520
# 4      False         Urgent  223880.93  22388.093  11194.0465
# 12     False            NaN  209676.25  20967.625  10483.8125
# 13     False  Promo Applied  307805.85  30780.585  15390.2925
# 58     False  Promo Applied   50500.84   5050.084   2525.0420
# 19     False     Bulk Order  139423.80  13942.380   6971.1900
# 59     False         Urgent  118612.13  11861.213   5930.6065
# 5       True         Urgent   96128.88   9612.888   4806.4440
# 17     False     Bulk Order  326521.23  32652.123  16326.0615
# 38     False         Urgent   36222.54   3622.254   1811.1270

# %% [markdown]
# ##### Row or Column-wise Function Application
#
# 🔹 apply() on DataFrame
#
# - apply() applies a function along an axis (rows or columns).
#
# `DataFrame.apply(func, axis=0, raw=False, result_type=None)`
# - axis=0 → function applied column-wise
#
# - axis=1 → function applied row-wise

# %%
# Column-wise Aggregation
df[["units", "revenue"]].apply(sum)
# Out:
# units          295.00
# revenue    8053847.74
# dtype: float64

# %%
# Row-wise Custom Function
def total_values(row):
    return row["units"] * row["unit_price"]

df["Computed Revenue"] = df.apply(total_values, axis=1)
df.head()
# Out:
#    order_id       date customer region     product  units  unit_price  \
# 0      2001 2025-01-01     Diya   East  Headphones      5    38319.36
# 1      2002 2025-01-02  Reyansh   East  Smartphone      7    12644.24
# 2      2003 2025-01-03      Sai  North  Headphones      7    36682.60
# 3      2004 2025-01-04     Sara  North  Smartphone      4    19021.37
# 4      2005 2025-01-05    Aditi   East      Laptop      7    31982.99
#
#    returned          notes    revenue  Computed Revenue
# 0     False            NaN  191596.80         191596.80
# 1     False  Promo Applied   88509.68          88509.68
# 2     False           Gift  256778.20         256778.20
# 3     False  Promo Applied   76085.48          76085.48
# 4     False         Urgent  223880.93         223880.93

# %%
df["revenue"] = df["revenue"].apply(lambda x: round(x, 1))
df.head()
# Out:
#    order_id       date customer region     product  units  unit_price  \
# 0      2001 2025-01-01     Diya   East  Headphones      5    38319.36
# 1      2002 2025-01-02  Reyansh   East  Smartphone      7    12644.24
# 2      2003 2025-01-03      Sai  North  Headphones      7    36682.60
# 3      2004 2025-01-04     Sara  North  Smartphone      4    19021.37
# 4      2005 2025-01-05    Aditi   East      Laptop      7    31982.99
#
#    returned          notes   revenue  Computed Revenue
# 0     False            NaN  191597.0         191596.80
# 1     False  Promo Applied   88510.0          88509.68
# 2     False           Gift  256778.0         256778.20
# 3     False  Promo Applied   76085.0          76085.48
# 4     False         Urgent  223881.0         223880.93

# %%
result = df[["units", "unit_price"]].map(lambda x: x * 2)
print(result.head())

# result = df["region"].map(lambda x: x.upper())
# print(result.head())
# Out:
#    units  unit_price
# 0     10    76638.72
# 1     14    25288.48
# 2     14    73365.20
# 3      8    38042.74
# 4     14    63965.98
# 0     East
# 1     East
# 2    North
# 3    North
# 4     East
# Name: region, dtype: object

# %%
discount_map = {"North": 0.05, "South": 0.1, "East": 0.08, "West": 0.06}
df["region_discount"] = df["region"].map(discount_map)
df.head()
# Out:
#    order_id       date customer region     product  units  unit_price  \
# 0      2001 2025-01-01     Diya   East  Headphones      5    38319.36
# 1      2002 2025-01-02  Reyansh   East  Smartphone      7    12644.24
# 2      2003 2025-01-03      Sai  North  Headphones      7    36682.60
# 3      2004 2025-01-04     Sara  North  Smartphone      4    19021.37
# 4      2005 2025-01-05    Aditi   East      Laptop      7    31982.99
#
#    returned          notes    revenue     profit    discount  region_discount
# 0     False            NaN  191596.80  19159.680   9579.8400             0.08
# 1     False  Promo Applied   88509.68   8850.968   4425.4840             0.08
# 2     False           Gift  256778.20  25677.820  12838.9100             0.05
# 3     False  Promo Applied   76085.48   7608.548   3804.2740             0.05
# 4     False         Urgent  223880.93  22388.093  11194.0465             0.08

# %% [markdown]
# #### Pandas - Reindexing
#
# Reindexing means changing the row or column labels of a DataFrame or Series to a new set of labels.
#
# It’s useful when:
#
# - You want to align two datasets by index
# - You want to fill in missing indices
# - You want to reorder or rename labels
#
# `DataFrame.reindex(labels=None, index=None, columns=None, method=None,
#                   fill_value=None, limit=None, tolerance=None, copy=True)
# `

# %%
new_index = [ 1, 2, 3, 4, 5, 6]
df_reindexed = df.reindex(new_index)
df_reindexed
# df.head()
# Out:
#    order_id       date customer region     product  units  unit_price  \
# 1      2002 2025-01-02  Reyansh   East  Smartphone      7    12644.24
# 2      2003 2025-01-03      Sai  North  Headphones      7    36682.60
# 3      2004 2025-01-04     Sara  North  Smartphone      4    19021.37
# 4      2005 2025-01-05    Aditi   East      Laptop      7    31982.99
# 5      2006 2025-01-06    Anika  South  Smartwatch      3    32042.96
# 6      2007 2025-01-07      Sai   West  Smartwatch      6    27252.96
#
#    returned          notes    revenue     profit    discount  region_discount
# 1     False  Promo Applied   88509.68   8850.968   4425.4840             0.08
# 2     False           Gift  256778.20  25677.820  12838.9100             0.05
# 3     False  Promo Applied   76085.48   7608.548   3804.2740             0.05
# 4     False         Urgent  223880.93  22388.093  11194.0465             0.08
# 5      True         Urgent   96128.88   9612.888   4806.4440             0.10
# 6     False           Gift  163517.76  16351.776   8175.8880             0.06

# %%
df1 = pd.DataFrame({"revenue": [1000, 2000, 3000]}, index=["A", "B", "C"])
df2 = pd.DataFrame({"profit": [100, 200]}, index=["A", "D"])

aligned = df1.reindex(df2.index)
print(aligned)
# reindex(df2.index) aligns df1’s data to match df2’s index.

# Where df2 has “D” (missing in df1), pandas inserts NaN.
# Out:
#    revenue
# A   1000.0
# D      NaN

# %% [markdown]
# 🔹 When to use apply():
#
# | Goal | Best Method |
# |---|---|
# |Entire DataFrame	| .pipe()
# |Each Row or Column	| .apply()
# |Each Element	  | .applymap() or .map()

# %% [markdown]
# ##### Element-wise Function Application
#
# Element-wise means each **individual cell** or value is processed by a function.
#
# - applymap() → applies to every element of the entire DataFrame
# -  map() → applies to each element of a Series

# %% [markdown]
# DataFrame.at
# - Access a single value for a row/column pair by label.
#
# DataFrame.iat
# - Access a single value for a row/column pair by integer position.
#
# DataFrame.loc
# - Access a group of rows and columns by label(s).
#
# DataFrame.iloc
# - Access a group of rows and columns by integer position(s).
#
# Series.at
# - Access a single value by label.
#
# Series.iat
# - Access a single value by integer position.
#
# Series.loc
# - Access a group of rows by label(s).
#
# Series.iloc
# - Access a group of rows by integer position(s).
